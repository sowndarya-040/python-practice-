# %% [markdown]
# # Iterable creation of set

# %%
s1 = {1,5,8}
type(s1)
# Out:
# set

# %%
s2 = {10,2,8,10,10,8}

# %%
s3 = {}

# %%
s4 = set()

# %%
s4 = set([1,5,3,8])

# %%
s1 = {1,2,5,7}

# %%
s4 = set(10)   # 'int' object is not iterable
print(s4)        # inside the set form a list it will give a output
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 s4 = set(10)   # 'int' object is not iterable
#       2 print(s4)
#
# TypeError: 'int' object is not iterable

# %%
s4 = set([10])
print(s4)
# Out:
# {10}

# %%
s4 = set([10, 5])
print(s4)
# Out:
# {10, 5}

# %%
s4 = set([10])

# %% [markdown]
# # Iterebles accesing ths element

# %%
s4 = {20,10,30,33,43}
for e in s4:
    print(e)
# Out:
# 33
# 20
# 10
# 43
# 30

# %%
for e in sorted(s4):
    s4.add(15)
    print(e)
# Out:
# 10
# 15
# 20
# 30
# 33
# 43

# %%
for e in add(s4):
    s4.add(15)
    print(e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 for e in add(s4):
#       2     s4.add(15)
#       3     print(e)
#
# NameError: name 'add' is not defined

# %%
s4 = {20,10,30,33,43}
s4.add(25)

# %%
s5 = {22,40,50,12,35}
for e in s5:
    print(s5)
# Out:
# {50, 35, 22, 40, 12}
# {50, 35, 22, 40, 12}
# {50, 35, 22, 40, 12}
# {50, 35, 22, 40, 12}
# {50, 35, 22, 40, 12}

# %%
s6 = {565,6257,442,345}
for e in s6:
    print(s6)
# Out:
# {345, 442, 6257, 565}
# {345, 442, 6257, 565}
# {345, 442, 6257, 565}
# {345, 442, 6257, 565}

# %% [markdown]
# # Iterables build in methods

# %%
s4 = {40,10,20,30}
print(len(s4))
# Out:
# 4

# %%
print(min(s4))
# Out:
# 10

# %%
print(max(s4))
# Out:
# 40

# %%
print(sum(s4))
# Out:
# 100

# %%
print(sorted(s4))
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# # Iterable comparion operation

# %%
s1 = {2,4,6,8}
s2 = {8,6,4,2}
print(s1==s2)
# Out:
# True

# %%
print(s1!=s2)
# Out:
# False

# %%
print(s1<s2)
# Out:
# False

# %%
print(s1<=s2)
# Out:
# True

# %%
print(s1>=s2)
# Out:
# True

# %%
#s4.update(44)    # TypeError: 'int' object is not iterable
s4 = {20,10,30,33,43}
s4.update((44,35,56))
print(s4)
# Out:
# {33, 35, 20, 56, 10, 43, 44, 30}

# %% [markdown]
# # Iterable set object method

# %%
s4 = {40,20,30,10}
s4.add(100)
# s4.add(2,100)
# TypeError: set.add() takes exactly one argument (2 given) ex: s4.add(2,100) it will give the type Error 
# same function add one more paranthesis or tuples[ set.add(()) ] will give the output
s4.add((2,100))
print(s4)
# Out:
# {100, 40, 10, (2, 100), 20, 30}

# %%
s3 = {10,20,30}
s3.update((11,22))
print(s3)
# Out:
# {10, 11, 20, 22, 30}
