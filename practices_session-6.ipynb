# %% [markdown]
# # List Method

# %%
l1 = list("name")
print(l1)
# Out:
# ['n', 'a', 'm', 'e']

# %%
l1 = list(10)      # 'int' object is not iterable
print(l1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 l1 = list(10)
#       2 print(l1)
#
# TypeError: 'int' object is not iterable

# %%
l2 = list(22.5)  # TypeError: 'float' object is not iterable
print(l2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 l2 = list(22.5)
#       2 print(l2)
#
# TypeError: 'float' object is not iterable

# %% [markdown]
# l2 = list(argument)
# print(l2)

# %%
l1 = [1,2,3]
l2 = [2,1,3]
l1==l2
# Out:
# False

# %%
l1 = [1,2,3]
l2 = [1,2,3]
l1==l2
# Out:
# True

# %% [markdown]
# # concatinate operation

# %%
L1 = [22,34,45,45]
L2 = [33,44,55,66]
print(L1 +L2)
# Out:
# [22, 34, 45, 45, 33, 44, 55, 66]

# %%
print(L1 * 3)
# Out:
# [22, 34, 45, 45, 22, 34, 45, 45, 22, 34, 45, 45]

# %%
data = (10, "Python", 3.14)
print(data)
# Out:
# (10, 'Python', 3.14)

# %%
r1 = [22,34,45,45,60,66,11,10,20,30]
print(r1[0:5])
# Out:
# [22, 34, 45, 45, 60]

# %%
r1[0:5]
# Out:
# [22, 34, 45, 45, 60]

# %%
r1[:8]
# Out:
# [22, 34, 45, 45, 60, 66, 11, 10]

# %%
r1[:4]
# Out:
# [22, 34, 45, 45]

# %%
r1[5:]
# Out:
# [66, 11, 10, 20, 30]

# %%
r1[-3:]
# Out:
# [10, 20, 30]

# %%
r1[:-2]
# Out:
# [22, 34, 45, 45, 60, 66, 11, 10]

# %%
r1[::2]
# Out:
# [22, 45, 60, 11, 20]

# %%
r1[1::2]
# Out:
# [34, 45, 66, 10, 30]

# %%
r1[::-1]
# Out:
# [30, 20, 10, 11, 66, 60, 45, 45, 34, 22]

# %%
r1[8:2:-1]
# Out:
# [20, 10, 11, 66, 60, 45]
